# %%
import pandas as pd
import numpy  as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn import naive_bayes
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import spacy
import re

# %%
data_origin = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')

# %%
vect = CountVectorizer(min_df=5, stop_words="english").fit(data_origin.description)

# %%
x_train = vect.transform(data_origin.description)

# %%
print("x_train:\n {}".format(repr(x_train)))
# Out:
# x_train:
#  <2931x1063 sparse matrix of type '<class 'numpy.int64'>'
# 	with 24089 stored elements in Compressed Sparse Row format>

# %%
feature_names = vect.get_feature_names()
print("Number of features: {}".format(len(feature_names)))
print("First 20 features:\n{}".format(feature_names[:20]))
print("Features 2000 to 2020:\n{}".format(feature_names[500:520]))
print("Every 200th features:\n{}".format(feature_names[::200]))
# Out:
# Number of features: 1063
# First 20 features:
# ['ability', 'able', 'abreast', 'acceptance', 'access', 'accordance', 'according', 'account', 'accuracy', 'accurate', 'accurately', 'achieve', 'acquisition', 'act', 'action', 'actionable', 'actions', 'active', 'actively', 'activities']
# Features 2000 to 2020:
# ['inspection', 'inspections', 'installation', 'integrate', 'integrated', 'integrates', 'integrating', 'integration', 'integrity', 'intelligence', 'interact', 'interaction', 'interactions', 'interface', 'interfaces', 'internal', 'interpret', 'investigate', 'investigations', 'issue']
# Every 200th features:
# ['ability', 'consulting', 'fine', 'meets', 'regarding', 'translating']

# %%
cv = CountVectorizer(ngram_range=(1,1)).fit(data_origin.description)
print("Vocabulary size:{}".format(len(cv.vocabulary_)))
print("Vocabulary:\n{}".format(cv.get_feature_names()))
# Out:
# Vocabulary size:4324
# Vocabulary:
# ['000', '10', '11', '20', '2003', '2008', '2012', '2013', '2016', '24', '25', '260', '2d', '30', '32', '36', '365', '3d', '3rd', '40', '50', '500', '500m', '523', '5g', '64', '70', 'ab', 'abilities', 'ability', 'able', 'about', 'above', 'abreast', 'abroad', 'absent', 'abstracting', 'abstractions', 'academic', 'acc', 'accelerate', 'acceleration', 'accelerator', 'acceptable', 'acceptance', 'accepted', 'access', 'accessibility', 'accessible', 'accessories', 'accident', 'accommodating', 'accompany', 'accomplish', 'accomplished', 'accomplishes', 'accomplishing', 'accordance', 'according', 'accordingly', 'account', 'accountability', 'accountable', 'accountants', 'accounting', 'accounts', 'accuracy', 'accurate', 'accurately', 'achieve', 'achievement', 'achieving', 'acknowledgment', 'acoustic', 'acquire', 'acquires', 'acquisition', 'acquisitions', 'across', 'act', 'acting', 'action', 'actionable', 'actions', 'activates', 'activation', 'active', 'actively', 'activities', 'activity', 'actor', 'acts', 'actual', 'actuators', 'acute', 'ad', 'adapt', 'adaptations', 'adas', 'add', 'added', 'adding', 'addition', 'additional', 'address', 'addressed', 'addresses', 'adds', 'adept', 'adequacy', 'adequately', 'adhere', 'adhered', 'adherence', 'adheres', 'adhering', 'adjacent', 'adjuster', 'adjusters', 'adjusting', 'adjustment', 'adjustments', 'administer', 'administration', 'administrative', 'administrator', 'administrators', 'adobe', 'adopt', 'adopted', 'adopting', 'adoption', 'ads', 'advance', 'advanced', 'advancement', 'advancing', 'advantage', 'advantages', 'advice', 'advise', 'advisor', 'advisors', 'advisory', 'advocate', 'advocating', 'advocator', 'aeb', 'aerodynamic', 'aerospace', 'affect', 'affecting', 'afforded', 'afm', 'afraid', 'after', 'aftermarket', 'against', 'agencies', 'agency', 'agenda', 'aggregated', 'aggregation', 'aggressive', 'aggressively', 'agile', 'agreed', 'agreement', 'agreements', 'agriculture', 'ahri', 'ai', 'aid', 'aided', 'aids', 'air', 'aircraft', 'airflow', 'ajax', 'aka', 'alcatel', 'alcohol', 'alerting', 'alerts', 'algorithm', 'algorithmic', 'algorithms', 'align', 'aligned', 'alignment', 'alike', 'all', 'allocate', 'allocates', 'allocation', 'allow', 'alone', 'along', 'alongside', 'also', 'alternative', 'alternatives', 'although', 'always', 'ambassador', 'ambitious', 'amend', 'amendment', 'amendments', 'among', 'amount', 'amounts', 'amplifiers', 'an', 'analyse', 'analyses', 'analysis', 'analyst', 'analysts', 'analytic', 'analytical', 'analytics', 'analyzable', 'analyze', 'analyzer', 'analyzes', 'analyzing', 'and', 'andcontinuous', 'android', 'angular', 'angularjs', 'annotation', 'announcements', 'annual', 'annually', 'anomalies', 'anomaly', 'answer', 'answering', 'answers', 'anticipate', 'anticipated', 'anticipating', 'any', 'anyone', 'apache', 'apartment', 'apartments', 'apex', 'api', 'apis', 'app', 'appealing', 'appear', 'appearance', 'appfluent', 'applicability', 'applicable', 'applicant', 'application', 'applications', 'applied', 'applies', 'apply', 'applying', 'appointment', 'appointments', 'approach', 'approaches', 'appropriate', 'appropriately', 'approval', 'approve', 'approved', 'approx', 'approximately', 'apps', 'ar', 'arc', 'archetypes', 'architect', 'architecting', 'architects', 'architectural', 'architecture', 'architectures', 'archives', 'are', 'area', 'areas', 'arguments', 'arising', 'arm', 'armed', 'around', 'array', 'arrive', 'art', 'articles', 'articulate', 'artifacts', 'artificial', 'artists', 'as', 'ashrae', 'asking', 'asp', 'aspects', 'asr', 'assemble', 'assemblies', 'assembly', 'assess', 'assessing', 'assessment', 'assessments', 'asset', 'assets', 'assign', 'assigned', 'assignments', 'assist', 'assistance', 'assisting', 'assists', 'associate', 'associates', 'assume', 'assumptions', 'assurance', 'assure', 'astute', 'at', 'atl', 'atom', 'atomsphere', 'attend', 'attendance', 'attends', 'attention', 'attentive', 'attitude', 'attract', 'auction', 'audience', 'audiences', 'audio', 'audit', 'auditing' ...

# %%
cv = CountVectorizer(ngram_range=(2,2)).fit(data_origin.description)
print("Vocabulary size:{}".format(len(cv.vocabulary_)))
print("Vocabulary:\n{}".format(cv.get_feature_names()))
# Out:
# Vocabulary size:22944
# Vocabulary:
# ['000 computing', '10 cm', '10 of', '20 overnight', '20 staff', '2003 2013', '2008 2012', '2012 2016', '2013 office', '24 global', '25 backend', '25 middle', '25 pounds', '25 travel', '260 pci', '2d and', '30 of', '32 64', '32 bit', '36 523', '365 crm', '365 platforms', '3d engineering', '3d seismic', '3d visualizations', '3rd party', '40 50', '50 front', '50 travel', '500 000', '500m records', '523 cr', '5g fdd', '5g ue', '64 bit', '70 large', 'ab beckhoff', 'ab sew', 'ab siemens', 'abilities for', 'abilities of', 'ability and', 'ability in', 'ability of', 'ability to', 'ability tomonitor', 'ability tomulti', 'able to', 'about and', 'about customer', 'about how', 'about incoming', 'about machine', 'about new', 'about product', 'about progress', 'about the', 'about their', 'about workflows', 'above customers', 'above in', 'above studies', 'above to', 'abreast of', 'abstracting and', 'abstractions and', 'academic and', 'academic community', 'academic institutions', 'acc lane', 'accelerate development', 'acceleration and', 'accelerator software', 'acceptable process', 'acceptance and', 'acceptance fire', 'acceptance including', 'acceptance test', 'acceptance testing', 'acceptance tests', 'accepted or', 'accepted secure', 'access best', 'access configuration', 'access event', 'access information', 'access key', 'access memory', 'access to', 'access using', 'access within', 'accessibility standards', 'accessible data', 'accessories etc', 'accident investigations', 'accident reports', 'accommodating unique', 'accompany customer', 'accomplish goals', 'accomplish project', 'accomplished with', 'accomplishes great', 'accomplishing assigned', 'accomplishing goals', 'accordance to', 'accordance with', 'according to', 'account for', 'account leadership', 'account management', 'account managers', 'accountability drive', 'accountability for', 'accountable for', 'accountable to', 'accountants to', 'accounting and', 'accounting or', 'accounts prepare', 'accuracy and', 'accuracy clarity', 'accuracy develop', 'accuracy of', 'accuracy performance', 'accuracy tooling', 'accurate and', 'accurate available', 'accurate basis', 'accurate client', 'accurate data', 'accurate documentation', 'accurate machine', 'accurate orders', 'accurate relevant', 'accurate timelines', 'accurate vehicle', 'accurately address', 'accurately logging', 'accurately maintaining', 'accurately measure', 'accurately prove', 'achieve and', 'achieve business', 'achieve by', 'achieve compliance', 'achieve defined', 'achieve desired', 'achieve goals', 'achieve greater', 'achieve on', 'achieve organizational', 'achieve pack', 'achieve sales', 'achieve success', 'achieve team', 'achieve the', 'achieve their', 'achieve them', 'achievement of', 'achieving developmental', 'achieving sales', 'acknowledgment of', 'acoustic modeling', 'acquire and', 'acquire expand', 'acquires new', 'acquisition analysis', 'acquisition and', 'acquisition of', 'acquisition pipeline', 'acquisition programming', 'acquisition to', 'acquisitions and', 'across ads', 'across all', 'across brands', 'across broad', 'across business', 'across campus', 'across cloud', 'across critical', 'across data', 'across departments', 'across different', 'across diverse', 'across entire', 'across groups', 'across iis', 'across industries', 'across it', 'across known', 'across multi', 'across multiple', 'across national', 'across product', 'across regions', 'across several', 'across silos', 'across strategic', 'across teams', 'across the', 'across unicef', 'across variety', 'across various', 'across whole', 'act as', 'act independently', 'acting as', 'acting upon', 'action and', 'action documentation', 'action identification', 'action implementation', 'action items', 'action of', 'action our', 'action performed', 'action planning', 'action plans', 'action poa', 'action to', 'actionable and', 'actionable data', 'actionable experimental', 'actionable form', 'actionable impactful', 'actionable insight', 'actionable insights', 'ac ...

# %%
regexp = re.compile('(?u)\\b\\w\\w+\\b')

# %%
en_nlp = spacy.load('en')
old_tokenizer = en_nlp.tokenizer
en_nlp.tokenizer = lambda string: old_tokenizer.tokens_from_list(regexp.findall(string))

# %%
def custom_tokenizer(document):
    doc_spacy = en_nlp(document)
    return [token.lemma_ for token in doc_spacy]

# %%
lemma_vect = CountVectorizer(tokenizer=custom_tokenizer,min_df=5,stop_words="english",ngram_range=(1,3))

# %%
x_train_lemma = lemma_vect.fit_transform(data_origin.description)
# Out:
# C:\Users\masato\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: [W002] Tokenizer.from_list is now deprecated. Create a new Doc object instead and pass in the strings as the `words` keyword argument, for example:
# from spacy.tokens import Doc
# doc = Doc(nlp.vocab, words=[...])
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print("x_train_lemma.shape:{}".format(x_train_lemma.shape))
# Out:
# x_train_lemma.shape:(2931, 1382)

# %%
vect = CountVectorizer(min_df=5,stop_words="english",ngram_range=(1,3)).fit(data_origin.description)
x_train = vect.transform(data_origin.description)
print("x_train.shape:{}".format(x_train.shape))
# Out:
# x_train.shape:(2931, 1431)
